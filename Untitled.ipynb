# %%
import cv2

# %%
from deepface import DeepFace
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
img = cv2.imread('happy_woman.webp')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:07<00:00,  1.88s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 6.104728631906168e-11,
#    'disgust': 5.797577645196085e-24,
#    'fear': 6.060833773129908e-16,
#    'happy': 99.44682714026136,
#    'sad': 3.3078023630159626e-11,
#    'surprise': 2.9105302126829504e-07,
#    'neutral': 0.5531756071403985},
#   'dominant_emotion': 'happy',
#   'region': {'x': 275, 'y': 42, 'w': 182, 'h': 182},
#   'age': 32,
#   'gender': {'Woman': 99.99973773956299, 'Man': 0.0002668376282599638},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 13.747374713420868,
#    'indian': 21.826379001140594,
#    'black': 41.95905029773712,
#    'white': 1.5040520578622818,
#    'middle eastern': 1.638769917190075,
#    'latino hispanic': 19.324374198913574},
#   'dominant_race': 'black'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
           predictions[0]['dominant_emotion'],
           (10,80),
           font, 2,
           (0, 0, 255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad.jpeg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.4688913282091217,
#    'disgust': 0.00048657510150240874,
#    'fear': 0.15056311118978924,
#    'happy': 5.5659862616925925e-05,
#    'sad': 98.67986432789948,
#    'surprise': 2.1349551178268313e-08,
#    'neutral': 0.7001391097986167},
#   'dominant_emotion': 'sad',
#   'region': {'x': 98, 'y': 16, 'w': 109, 'h': 109},
#   'age': 29,
#   'gender': {'Woman': 95.82690000534058, 'Man': 4.1731055825948715},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 7.121760294227565,
#    'indian': 4.511856494920671,
#    'black': 0.8802110211299633,
#    'white': 39.25356993036629,
#    'middle eastern': 22.97961735968383,
#    'latino hispanic': 25.25297996366263},
#   'dominant_race': 'white'}]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'sad'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    font=cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
           predictions[0]['dominant_emotion'],
           (10,80),
           font, 2,
           (0, 0, 255),
           2,
           cv2.LINE_4);
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
